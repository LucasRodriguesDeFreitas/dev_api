# %%
from flask import Flask, json, request
import json

app = Flask(__name__)


desenvolvedores = [
    {'nome':'Rafael',
    'habilidades':['Python', 'Flask']
    },
    {'nome':'Lucas',
    'habilidades':['Python', 'SQL']}
]



@app.route('/dev/<int:id>/', methods=['GET', 'PUT'])

def desenvolvedor(id):
    if request.method == 'GET':
        desenvolvedor = desenvolvedores[id]
        print(desenvolvedor)
        return jsonify(desenvolvedor)
    elif request.method == 'PUT':
        dados = json.loads(request.data)
        desenvolvedor[id] = dados
        return jsonify(dados)


if __name__ == '__main__':
    app.run()
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)
# [2023-03-16 19:15:11,964] ERROR in app: Exception on /dev/1/ [PUT]
# Traceback (most recent call last):
#   File "C:\Users\lucas.freitas\Anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\lucas.freitas\Anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\lucas.freitas\Anaconda3\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "C:\Users\lucas.freitas\Anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "C:\Users\lucas.freitas\Anaconda3\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\lucas.freitas\Anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "C:\Users\lucas.freitas\AppData\Local\Temp\ipykernel_15672\3871405128.py", line 25, in desenvolvedor
#     dados = json.loads(request.data)
#   File "C:\Users\lucas.freitas\Anaconda3\lib\json\__init__.py", line 346, in loads
#     return _default_decoder.decode(s)
#   File "C:\Users\lucas.freitas\Anaconda3\lib\json\decoder.py", line 337, in decode
#     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#   File "C:\Users\lucas.freitas\Anaconda3\lib\json\decoder.py", line 353, in raw_decode
#     obj, end = self.scan_once(s, idx)
# json.decoder.JSONDecodeError: Expecting property name enclosed in double quotes: line 1 column 2 (char 1)
# 127.0.0.1 - - [16/Mar/2023 19:15:11] "PUT /dev/1/ HTTP/1.1" 500 -
# [2023-03-16 19:15:25,645] ERROR in app: Exception on /dev/1/ [GET]
# Traceback (most recent call last):
#   File "C:\Users\lucas.freitas\Anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\lucas.freitas\Anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\lucas.freitas\Anaconda3\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "C:\Users\lucas.freitas\Anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "C:\Users\lucas.freitas\Anaconda3\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\lucas.freitas\Anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "C:\Users\lucas.freitas\AppData\Local\Temp\ipykernel_15672\3871405128.py", line 23, in desenvolvedor
#     return jsonify(desenvolvedor)
# NameError: name 'jsonify' is not defined
# 127.0.0.1 - - [16/Mar/2023 19:15:25] "GET /dev/1/ HTTP/1.1" 500 -
# {'nome': 'Lucas', 'habilidades': ['Python', 'SQL']}
# [2023-03-16 19:15:57,547] ERROR in app: Exception on /dev/1/ [PUT]
# Traceback (most recent call last):
#   File "C:\Users\lucas.freitas\Anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\lucas.freitas\Anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\lucas.freitas\Anaconda3\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "C:\Users\lucas.freitas\Anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "C:\Users\lucas.freitas\Anaconda3\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\lucas.freitas\Anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "C:\Users\lucas.freitas\AppData\Local\Temp\ipykernel_15672\3871405128.py", line 25, in desenvolvedor
#     dados = json.loads(request.data)
#   File "C:\Users\lucas.freitas\Anaconda3\lib\json\__init__.py", line 346, in loads
#     return _default_decoder.decode(s)
#   File "C:\Users\lucas.freitas\Anaconda3\lib\json\decoder.py", line 337, in decode
#     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#   File "C:\Users\lucas.freitas\Anaconda3\lib\json\decoder.py", line 353, in raw_decode
#     obj, end = self.scan_once(s, idx)
# json.decoder.JSONDecodeError: Expecting property name enclosed in double quotes: line 1 column 2 (char 1)
# 127.0.0.1 - - [16/Mar/2023 19:15:57] "PUT /dev/1/ HTTP/1.1" 500 -
# [2023-03-16 19:16:01,226] ERROR in app: Exception on /dev/1/ [PUT]
# Traceback (most recent call last):
#   File "C:\Users\lucas.freitas\Anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\lucas.freitas\Anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\lucas.freitas\Anaconda3\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "C:\Users\lucas.freitas\Anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "C:\Users\lucas.freitas\Anaconda3\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\lucas.freitas\Anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "C:\Users\lucas.freitas\AppData\Local\Temp\ipykernel_15672\3871405128.py", line 25, in desenvolvedor
#     dados = json.loads(request.data)
#   File "C:\Users\lucas.freitas\Anaconda3\lib\json\__init__.py", line 346, in loads
#     return _default_decoder.decode(s)
#   File "C:\Users\lucas.freitas\Anaconda3\lib\json\decoder.py", line 337, in decode
#     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#   File "C:\Users\lucas.freitas\Anaconda3\lib\json\decoder.py", line 353, in raw_decode
#     obj, end = self.scan_once(s, idx)
# json.decoder.JSONDecodeError: Expecting property name enclosed in double quotes: line 1 column 2 (char 1)
# 127.0.0.1 - - [16/Mar/2023 19:16:01] "PUT /dev/1/ HTTP/1.1" 500 -
# [2023-03-16 19:16:01,828] ERROR in app: Exception on /dev/1/ [PUT]
# Traceback (most recent call last):
#   File "C:\Users\lucas.freitas\Anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\lucas.freitas\Anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\lucas.freitas\Anaconda3\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "C:\Users\lucas.freitas\Anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "C:\Users\lucas.freitas\Anaconda3\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\lucas.freitas\Anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "C:\Users\lucas.freitas\AppData\Local\Temp\ipykernel_15672\3871405128.py", line 25, in desenvolvedor
#     dados = json.loads(request.data)
#   File "C:\Users\lucas.freitas\Anaconda3\lib\json\__init__.py", line 346, in loads
#     return _default_decoder.decode(s)
#   File "C:\Users\lucas.freitas\Anaconda3\lib\json\decoder.py", line 337, in decode
#     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#   File "C:\Users\lucas.freitas\Anaconda3\lib\json\decoder.py", line 353, in raw_decode
#     obj, end = self.scan_once(s, idx)
# json.decoder.JSONDecodeError: Expecting property name enclosed in double quotes: line 1 column 2 (char 1)
# 127.0.0.1 - - [16/Mar/2023 19:16:01] "PUT /dev/1/ HTTP/1.1" 500 -
# [2023-03-16 19:16:02,498] ERROR in app: Exception on /dev/1/ [PUT]
# Traceback (most recent call last):
#   File "C:\Users\lucas.freitas\Anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\lucas.freitas\Anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\lucas.freitas\Anaconda3\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "C:\Users\lucas.freitas\Anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "C:\Users\lucas.freitas\Anaconda3\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\lucas.freitas\Anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "C:\Users\lucas.freitas\AppData\Local\Temp\ipykernel_15672\3871405128.py", line 25, in desenvolvedor
#     dados = json.loads(request.data)
#   File "C:\Users\lucas.freitas\Anaconda3\lib\json\__init__.py", line 346, in loads
#     return _default_decoder.decode(s)
#   File "C:\Users\lucas.freitas\Anaconda3\lib\json\decoder.py", line 337, in decode
#     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#   File "C:\Users\lucas.freitas\Anaconda3\lib\json\decoder.py", line 353, in raw_decode
#     obj, end = self.scan_once(s, idx)
# json.decoder.JSONDecodeError: Expecting property name enclosed in double quotes: line 1 column 2 (char 1)
# 127.0.0.1 - - [16/Mar/2023 19:16:02] "PUT /dev/1/ HTTP/1.1" 500 -
# [2023-03-16 19:16:02,927] ERROR in app: Exception on /dev/1/ [PUT]
# Traceback (most recent call last):
#   File "C:\Users\lucas.freitas\Anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\lucas.freitas\Anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\lucas.freitas\Anaconda3\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "C:\Users\lucas.freitas\Anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "C:\Users\lucas.freitas\Anaconda3\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\lucas.freitas\Anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "C:\Users\lucas.freitas\AppData\Local\Temp\ipykernel_15672\3871405128.py", line 25, in desenvolvedor
#     dados = json.loads(request.data)
#   File "C:\Users\lucas.freitas\Anaconda3\lib\json\__init__.py", line 346, in loads
#     return _default_decoder.decode(s)
#   File "C:\Users\lucas.freitas\Anaconda3\lib\json\decoder.py", line 337, in decode
#     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#   File "C:\Users\lucas.freitas\Anaconda3\lib\json\decoder.py", line 353, in raw_decode
#     obj, end = self.scan_once(s, idx)
# json.decoder.JSONDecodeError: Expecting property name enclosed in double quotes: line 1 column 2 (char 1)
# 127.0.0.1 - - [16/Mar/2023 19:16:02] "PUT /dev/1/ HTTP/1.1" 500 -
# [2023-03-16 19:16:07,389] ERROR in app: Exception on /dev/1/ [PUT]
# Traceback (most recent call last):
#   File "C:\Users\lucas.freitas\Anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\lucas.freitas\Anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\lucas.freitas\Anaconda3\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "C:\Users\lucas.freitas\Anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "C:\Users\lucas.freitas\Anaconda3\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\lucas.freitas\Anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "C:\Users\lucas.freitas\AppData\Local\Temp\ipykernel_15672\3871405128.py", line 25, in desenvolvedor
#     dados = json.loads(request.data)
#   File "C:\Users\lucas.freitas\Anaconda3\lib\json\__init__.py", line 346, in loads
#     return _default_decoder.decode(s)
#   File "C:\Users\lucas.freitas\Anaconda3\lib\json\decoder.py", line 337, in decode
#     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#   File "C:\Users\lucas.freitas\Anaconda3\lib\json\decoder.py", line 353, in raw_decode
#     obj, end = self.scan_once(s, idx)
# json.decoder.JSONDecodeError: Expecting property name enclosed in double quotes: line 1 column 2 (char 1)
# 127.0.0.1 - - [16/Mar/2023 19:16:07] "PUT /dev/1/ HTTP/1.1" 500 -
# [2023-03-16 19:16:16,320] ERROR in app: Exception on /dev/1/ [PUT]
# Traceback (most recent call last):
#   File "C:\Users\lucas.freitas\Anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\lucas.freitas\Anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\lucas.freitas\Anaconda3\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "C:\Users\lucas.freitas\Anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "C:\Users\lucas.freitas\Anaconda3\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\lucas.freitas\Anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "C:\Users\lucas.freitas\AppData\Local\Temp\ipykernel_15672\3871405128.py", line 25, in desenvolvedor
#     dados = json.loads(request.data)
#   File "C:\Users\lucas.freitas\Anaconda3\lib\json\__init__.py", line 346, in loads
#     return _default_decoder.decode(s)
#   File "C:\Users\lucas.freitas\Anaconda3\lib\json\decoder.py", line 337, in decode
#     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#   File "C:\Users\lucas.freitas\Anaconda3\lib\json\decoder.py", line 353, in raw_decode
#     obj, end = self.scan_once(s, idx)
# json.decoder.JSONDecodeError: Expecting property name enclosed in double quotes: line 1 column 2 (char 1)
# 127.0.0.1 - - [16/Mar/2023 19:16:16] "PUT /dev/1/ HTTP/1.1" 500 -
# [2023-03-16 19:16:18,948] ERROR in app: Exception on /dev/1/ [PUT]
# Traceback (most recent call last):
#   File "C:\Users\lucas.freitas\Anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\lucas.freitas\Anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\lucas.freitas\Anaconda3\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "C:\Users\lucas.freitas\Anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "C:\Users\lucas.freitas\Anaconda3\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\lucas.freitas\Anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "C:\Users\lucas.freitas\AppData\Local\Temp\ipykernel_15672\3871405128.py", line 25, in desenvolvedor
#     dados = json.loads(request.data)
#   File "C:\Users\lucas.freitas\Anaconda3\lib\json\__init__.py", line 346, in loads
#     return _default_decoder.decode(s)
#   File "C:\Users\lucas.freitas\Anaconda3\lib\json\decoder.py", line 337, in decode
#     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#   File "C:\Users\lucas.freitas\Anaconda3\lib\json\decoder.py", line 353, in raw_decode
#     obj, end = self.scan_once(s, idx)
# json.decoder.JSONDecodeError: Expecting property name enclosed in double quotes: line 1 column 2 (char 1)
# 127.0.0.1 - - [16/Mar/2023 19:16:18] "PUT /dev/1/ HTTP/1.1" 500 -
# [2023-03-16 19:16:21,624] ERROR in app: Exception on /dev/1/ [PUT]
# Traceback (most recent call last):
#   File "C:\Users\lucas.freitas\Anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\lucas.freitas\Anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\lucas.freitas\Anaconda3\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "C:\Users\lucas.freitas\Anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "C:\Users\lucas.freitas\Anaconda3\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\lucas.freitas\Anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "C:\Users\lucas.freitas\AppData\Local\Temp\ipykernel_15672\3871405128.py", line 25, in desenvolvedor
#     dados = json.loads(request.data)
#   File "C:\Users\lucas.freitas\Anaconda3\lib\json\__init__.py", line 346, in loads
#     return _default_decoder.decode(s)
#   File "C:\Users\lucas.freitas\Anaconda3\lib\json\decoder.py", line 337, in decode
#     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#   File "C:\Users\lucas.freitas\Anaconda3\lib\json\decoder.py", line 353, in raw_decode
#     obj, end = self.scan_once(s, idx)
# json.decoder.JSONDecodeError: Expecting property name enclosed in double quotes: line 1 column 2 (char 1)
# 127.0.0.1 - - [16/Mar/2023 19:16:21] "PUT /dev/1/ HTTP/1.1" 500 -
